# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !rm -r pytorch-unet-master
# !cp -r drive/My\ Drive/pytorch-unet-master/* . 
# !cp -r drive/My\ Drive/neural_9o_e3amhno/* .

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os,sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import helper
import simulation

# %%
# !cp -r drive/My\ Drive/Nisia.tar.gz . 
# !tar -xvzf Nisia.tar.gz 
# !ls
# Out:
# Nisia/Paxoi/Paxoi_corine.tfw
# Nisia/Kerkira/Ker_corine.tif
# Nisia/North_Zakinthos/N_Zak_RGB.tif
# Nisia/Paxoi/Paxoi_rgb.tfw
# Nisia/Kerkira/Ker_corine.tif.ovr
# Nisia/North_Zakinthos/N_Zak_yper.tif.ovr
# Nisia/Leukada/Leuk_RGB.tfw
# Nisia/Kefalonia/Kef_RGB.tfw
# Nisia/Leukada/Leuk_RGB.tif.aux.xml
# Nisia/Kefalonia/
# Nisia/North_Zakinthos/N_Zak_yper.tif
# Nisia/Kefalonia/Kef_corine.tif
# Nisia/Paxoi/Paxoi_corine.tif.aux.xml
# Nisia/North_Zakinthos/N_Zaki_corine.tif.vat.cpg
# Nisia/Kerkira/Ker_corine.tif.aux.xml
# Nisia/Leukada/Leuk_yper.tif.aux.xml
# Nisia/Leukada/
# Nisia/Leukada/Leuk_corine.tfw
# Nisia/Leukada/Leuk_RGB.tif.ovr
# Nisia/North_Zakinthos/N_Zaki_corine.tif.vat.dbf
# Nisia/Paxoi/Paxoi_rgb.tif.aux.xml
# Nisia/Kefalonia/Kef_yper.tif.aux.xml
# Nisia/North_Zakinthos/N_Zak_RGB.tif.ovr
# Nisia/Leukada/Leuk_corine.tif.aux.xml
# Nisia/Paxoi/Paxoi_yper.tif
# Nisia/North_Zakinthos/N_Zak_RGB.tif.aux.xml
# Nisia/Kefalonia/Kef_corine.tif.aux.xml
# Nisia/Leukada/Leuk_yper.tfw
# ...

# %%
# !sudo add-apt-repository ppa:ubuntugis/ppa
# !sudo apt-get update
# !sudo apt-get install gdal-bin libgdal-dev
# !pip install -U pip
# !pip install rasterio
# Out:
#  Official stable UbuntuGIS packages.
#
#
#  More info: https://launchpad.net/~ubuntugis/+archive/ubuntu/ppa
# Press [ENTER] to continue or Ctrl-c to cancel adding it.
#
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:9 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import rasterio as rio
from rasterio.plot import show
# with rio.open(r'/home/bill/Λήψεις/Kef/Kef_raster.tif') as src_plot:
#     print(src_plot.read([1]).shape)
#     print(src_plot.read([2]).shape)
#     print(src_plot.read([3]).shape)
#     print(src_plot.read([4]).shape)
#     show(src_plot.read([1]))
    

    
# from PIL import Image
# import numpy as np

# im = Image.open('/home/bill/Λήψεις/Kef/Corine_kef.tif')

# # im = Image.open('/home/bill/kefalonia_test.tif')
import cv2
import numpy as np
# imarray = cv2.resize(np.array(im), dsize=(5145,5483), interpolation=cv2.INTER_NEAREST )
# # 11  56  57  65  67  68  76  77 111 112 121 123 124 131 142 155 211 221
# # 223 231 242 243



# im=np.array(im)
# print(np.unique(im))
# bl = imarray[:,:]==243
# bl=bl.reshape(imarray.shape)
# print(bl.shape)
# # imarray=bl
# plt.plot(imarray)
# from matplotlib import pyplot as plt
# plt.imshow(imarray)
# plt.show()
# print(imarray.shape)
# print(imarray)
# print(np.unique(imarray))
# print(len(np.unique(imarray)))
# # _ = plt.hist(imarray, bins='auto')  # arguments are passed to np.histogram
# # plt.title("Histogram with 'auto' bins")

# # plt.show()

import numpy as np
from osgeo import gdal
# ds = gdal.Open("/home/bill/Λήψεις/Kef/Kef_raster.tif")
# myarray = np.array(ds.GetRasterBand(1).ReadAsArray())
# plt.imshow(myarray[3000:3512,3000:3512])
# plt.title('X.Band1: Infrared')
# plt.show()
# plt.imshow(imarray[3000:3512,3000:3512])
# plt.title('y: clc')
# plt.show()




import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import rasterio as rio
from rasterio.plot import show
# dim=0
# with rio.open(r'/home/bill/Λήψεις/Nisia//Kefalonia/Kef_RGB.tif') as src_plot:
#     print(src_plot.read([1]).shape)
#     print(src_plot.read([2]).shape)
#     print(src_plot.read([3]).shape)
#     print(src_plot.read([4]).shape)
#     dim=src_plot.read([4]).shape
#     dim=dim[1:3]
#     dim=dim[::-1]
#     show(src_plot.read([1]))
    

    
# from PIL import Image
# import numpy as np

# im = Image.open('/home/bill/Λήψεις/Nisia//Kefalonia/Kef_corine.tif')
# im = np.array(im).astype('float32')
# # # im = Image.open('/home/bill/kefalonia_test.tif')
# import cv2
# import numpy as np
# print(dim)
# imarray = cv2.resize(np.array(im), dsize=dim, interpolation=cv2.INTER_CUBIC )
# # # 11  56  57  65  67  68  76  77 111 112 121 123 124 131 142 155 211 221
# # # 223 231 242 243



# im=np.array(im)
# print(np.unique(im))
# bl = imarray[:,:]==243
# bl=bl.reshape(imarray.shape)
# print(bl.shape)
# # imarray=bl
# plt.plot(imarray)
# from matplotlib import pyplot as plt
# plt.imshow(imarray)
# plt.show()
# print(imarray.shape)
# print(imarray)
# print(np.unique(imarray))
# print(len(np.unique(imarray)))
# # _ = plt.hist(imarray, bins='auto')  # arguments are passed to np.histogram
# # plt.title("Histogram with 'auto' bins")

# plt.show()

# import numpy as np
# from osgeo import gdal
# ds = gdal.Open("/home/bill/Λήψεις/Kef/Kef_raster.tif")
# myarray = np.array(ds.GetRasterBand(1).ReadAsArray())
# plt.imshow(myarray[3000:4512,3000:4512])
# plt.title('X.Band1: Infrared')
# plt.show()
# plt.imshow(imarray[3000:4512,3000:4512])
# plt.title('y: clc')
# plt.show()





def tiff2arr(corine_path, copernicus_path, infra_path):

    sent_size=320
    cor_size=32

    sent_hop=320
    cor_hop=32

    print("\n")
    X = [[],[],[],[]]
    Y = []
    import matplotlib.pyplot as plt
    dim=0
    with rio.open(copernicus_path) as src_plot:
        print('dim=',src_plot.read([4]).shape)
        dim=src_plot.read([4]).shape
        dim=dim[1:3]
        dim=dim[::-1]


    from PIL import Image
    import numpy as np

    im = Image.open(corine_path)
    im = np.array(im).astype('float32')
    cor_dim=im.shape
    print('corine dim=', im.shape)
    cor_dim=(int(dim[0]/10),int(dim[1]/10))
    # # im = Image.open('/home/bill/kefalonia_test.tif')
    import cv2
    import numpy as np
    imarray = cv2.resize(np.array(im), dsize=cor_dim, interpolation=cv2.INTER_NEAREST )
    # # 11  56  57  65  67  68  76  77 111 112 121 123 124 131 142 155 211 221
    # # 223 231 242 243
    dim=imarray.shape
    i=0
    while(i+cor_size<=dim[0]):
        j=0
        while(j+cor_size<=dim[1]):
            elem=imarray[i:i+cor_size,j:j+cor_size]
            Y.append(elem)
            j+=cor_hop
        i+=cor_hop
    
    
    
    
    import numpy as np
    from osgeo import gdal
    ds = gdal.Open(infra_path)
    myarray = np.array(ds.GetRasterBand(1).ReadAsArray())
    i=0
    dim=myarray.shape
    while(i+sent_size<=dim[0]):
        j=0
        while(j+sent_size<=dim[1]):
            X[0].append(myarray[i:i+sent_size,j:j+sent_size])
            j+=sent_hop
        i+=sent_hop
    
    
    
    color=['Red','Green','Blue']
    for band in range(1,4):
        ds = gdal.Open(copernicus_path)
        myarray = np.array(ds.GetRasterBand(band).ReadAsArray())
        i=0
        dim=myarray.shape
        while(i+sent_size<=dim[0]):
            j=0
            while(j+sent_size<=dim[1]):
                X[band].append(myarray[i:i+sent_size,j:j+sent_size])
                j+=sent_hop
            i+=sent_hop
        
    
    return X, Y
    
X1,Y1=tiff2arr('Nisia/Kefalonia/Kef_corine.tif', 'Nisia/Kefalonia/Kef_RGB.tif', 'Nisia/Kefalonia/Kef_yper.tif')
X2,Y2=tiff2arr('Nisia/Kerkira/Ker_corine.tif', 'Nisia/Kerkira/Ker_RGB.tif', 'Nisia/Kerkira/Ker_yper.tif')
X3,Y3=tiff2arr('Nisia/Leukada/Leuk_corine.tif', 'Nisia/Leukada/Leuk_RGB.tif', 'Nisia/Leukada/Leuk_yper.tif')
X4,Y4=tiff2arr('Nisia/North_Zakinthos/N_Zaki_corine.tif', 'Nisia/North_Zakinthos/N_Zak_RGB.tif', 'Nisia/North_Zakinthos/N_Zak_yper.tif')
X5,Y5=tiff2arr('Nisia/Paxoi/Paxoi_corine.tif', 'Nisia/Paxoi/Paxoi_rgb.tif', 'Nisia/Paxoi/Paxoi_yper.tif')

X = np.concatenate((X1, X2, X3, X4, X5), axis=1)
Y = np.concatenate((Y1, Y2, Y3, Y4, Y5), axis=0)

# dim= (1, 5559, 4684)
# corine dim= (556, 469)
# /n/n/n/n
# dim= (1, 2979, 2504)
# corine dim= (299, 251)
# /n/n/n/n
# dim= (1, 3250, 4678)
# corine dim= (326, 468)
# /n/n/n/n
# dim= (1, 785, 2498)
# corine dim= (79, 251)
# /n/n/n/n
# dim= (1, 1791, 2005)
# corine dim= (180, 201)
# Out:
# dim= (1, 5559, 4684)
# corine dim= (556, 469)
#
#
# dim= (1, 2979, 2504)
# corine dim= (299, 251)
#
#
# dim= (1, 3250, 4678)
# corine dim= (326, 468)
#
#
# dim= (1, 785, 2498)
# corine dim= (79, 251)
#
#
# dim= (1, 1791, 2005)
# corine dim= (180, 201)

# %%
import cv2
plt.imshow(Y1[141])
plt.title('y: clc')
plt.show()

plt.imshow(X1[0][141])
plt.title('x: sentinel2')
plt.show()

# %%
X1=np.array(X1)
Y1=np.array(Y1)
print(X1.shape)
print(Y1.shape)
print()
X2=np.array(X2)
Y2=np.array(Y2)
print(X2.shape)
print(Y2.shape)
print()
X3=np.array(X3)
Y3=np.array(Y3)
print(X3.shape)
print(Y3.shape)
print()
X4=np.array(X4)
Y4=np.array(Y4)
print(X4.shape)
print(Y4.shape)
print()
X5=np.array(X5)
Y5=np.array(Y5)
print(X5.shape)
print(Y5.shape)
print()

X0 = np.concatenate((X1, X2, X3, X4, X5), axis=1)
print(X0.shape)
Y0 = np.concatenate((Y1, Y2, Y3, Y4, Y5), axis=0)
print(Y0.shape)
# Out:
# (4, 238, 320, 320)
# (238, 32, 32)
#
# (4, 63, 320, 320)
# (63, 32, 32)
#
# (4, 140, 320, 320)
# (140, 32, 32)
#
# (4, 14, 320, 320)
# (14, 32, 32)
#
# (4, 30, 320, 320)
# (30, 32, 32)
#
# (4, 485, 320, 320)
# (485, 32, 32)

# %%
# (4, 653, 512, 512) -> (653, 512, 512, 4)
# (653, 512, 512)    -> (653, num_classes, 512, 512)

# print((np.unique(Y0)))
# [111. 112. 121. 123. 124. 131. 141. 142. 211. 221. 223. 231. 242. 243.
#  311. 312. 313. 321. 323. 324. 331. 332. 333. 411. 421. 422. 521. 522.
#  523.]
class_map=-1*np.ones(550)
class_map=np.array(class_map,dtype=int)
classes=[111, 112, 121, 123, 124, 131, 141, 142, 211, 221, 223, 231, 242, 243, 311, 312, 313, 321, 323, 324, 331, 332, 333, 411, 421, 422, 521, 522, 523]
for i in range(len(classes)):
    class_map[classes[i]]=i 

Y=np.zeros((485, 29, 32, 32), dtype=np.bool)

for n in range(485):
    print(n, end=' ')
    for i in range(32):
        for j in range(32):
            Y[n][class_map[int(Y0[n][i][j])]][i][j] = 1
    
    



X=np.zeros((485, 320, 320, 4), dtype=np.int16)
for n in range(485):
    print(n, end=' ')
    for i in range(320):
        for j in range(320):
            for k in range(4):
                X[n][i][j][k] = X0[k][n][i][j]

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os,sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import helper
import simulation
from joblib import dump, load

dump(X,'drive/My Drive/clc/X_320_nooverlap.joblib')
dump(Y,'drive/My Drive/clc/Y_32_nooverlap.joblib')

# !cp -r drive/My\ Drive/joblib/joblib320.tar.gz . 
# !tar -xvzf joblib320.tar.gz 
# !ls
# import pickle 


X=np.array(load('drive/My Drive/clc/X_320_nooverlap.joblib'),dtype=np.uint8)
Y=np.array(load('drive/My Drive/clc/Y_32_nooverlap.joblib'),dtype=np.float32)

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os,sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import helper
import simulation
from joblib import dump, load
X=np.array(load('drive/My Drive/neural_9o_e3amhno/X_320_nooverlap.joblib'),dtype=np.uint8)
Y=np.array(load('drive/My Drive/neural_9o_e3amhno/Y_32_nooverlap.joblib'),dtype=np.float32)

# %%
# (4, 653, 512, 512) -> (653, 512, 512, 4)
# (653, 512, 512)    -> (653, num_classes, 512, 512)

# print((np.unique(Y0)))
# [111. 112. 121. 123. 124. 131. 141. 142. 211. 221. 223. 231. 242. 243.
#  311. 312. 313. 321. 323. 324. 331. 332. 333. 411. 421. 422. 521. 522.
#  523.]

import numpy as np
import pickle 
from joblib import dump, load

class_map=-1*np.ones(550)
class_map=np.array(class_map,dtype=int)
classes=[111, 112, 121, 123, 124, 131, 141, 142, 211, 221, 223, 231, 242, 243, 311, 312, 313, 321, 323, 324, 331, 332, 333, 411, 421, 422, 521, 522, 523]
for i in range(len(classes)):
    class_map[classes[i]]=i 

#break dataset into 8 parts and save them to disc to avoid ram overflow

for w in range(7):
  X=np.zeros((1000, 320, 320, 4), dtype=np.int16)
  for n in range(1000):
      print(n, end=' ')
      for i in range(320):
          for j in range(320):
              for k in range(4):
                  X[n][i][j][k] = X0[k][w*1000+n][i][j].copy()

  dump(X,'drive/My Drive/clc/X_'+str(w)+'.joblib')
  

X=np.zeros((203, 320, 320, 4), dtype=np.int16)
for n in range(203):
    print(n, end=' ')
    for i in range(320):
        for j in range(320):
            for k in range(4):
                X[n][i][j][k] = X0[k][7000+n][i][j].copy()  

dump(X,'drive/My Drive/clc/X_'+str(7)+'.joblib')


for w in range(7):
  Y=np.zeros((1000, 29, 32, 32), dtype=np.bool)

  for n in range(1000):
      print(n, end=' ')
      for i in range(32):
          for j in range(32):
              Y[n][class_map[int(Y0[w*1000+n][i][j])]][i][j] = 1
  dump(Y,'drive/My Drive/clc/Y_'+str(w)+'.joblib')     


Y=np.zeros((203, 29, 32, 32), dtype=np.bool)

for n in range(203):
    print(n, end=' ')
    for i in range(32):
        for j in range(32):
            Y[n][class_map[int(Y0[7000+n][i][j])]][i][j] = 1
            
dump(Y,'drive/My Drive/clc/Y_'+str(7)+'.joblib')

# %%
# #use the 8 files (8 for X and 8 for Y) created above to break the dataset further so that each sample image consists one seperate file

# for w in range(7):
#   print()
#   X=load('drive/My Drive/clc/X_'+str(w)+'.joblib')
#   for n in range(1000):
#     print(n, end=' ')
#     tmp=X[n]
#     dump(tmp,'drive/My Drive/clc/X__'+str(w*1000+n)+'.joblib')
# print()
# X=load('drive/My Drive/clc/X_'+str(7)+'.joblib')
# for n in range(203):
#   print(n, end=' ')
#   tmp=X[n]
#   dump(tmp,'drive/My Drive/clc/X__'+str(7*1000+n)+'.joblib')


# for w in range(7):
#   print()
#   Y=load('drive/My Drive/clc/Y_'+str(w)+'.joblib')
#   for n in range(1000):
#     print(n, end=' ')
#     tmp=Y[n]
#     dump(tmp,'drive/My Drive/clc/Y__'+str(w*1000+n)+'.joblib')

# print()
# Y=load('drive/My Drive/clc/Y_'+str(7)+'.joblib')
# for n in range(203):
#   print(n, end=' ')
#   tmp=Y[n]
#   dump(tmp,'drive/My Drive/clc/Y__'+str(7*1000+n)+'.joblib')

# %%
# filter the dataset skipping plain sea images
import pickle 
from joblib import dump, load


idx=0


for w in range(7203):
  # if w%100 == 0:
  #   print(w, end=' ')
  Y=load('drive/My Drive/clc/Y__'+str(w)+'.joblib')

  cnt=0
  for c in range(29):
    if np.sum(Y[c]) > 0:
      cnt+=1
  if cnt>1:
    # X=load('drive/My Drive/clc/X__'+str(w)+'.joblib')
    # dump(X,'drive/My Drive/clc/Xf__'+str(idx)+'.joblib')
    # dump(Y,'drive/My Drive/clc/Yf__'+str(idx)+'.joblib')
    idx+=1

  if w == 3629:
    print('Kefalonia: last idx=',idx-1)
  elif w == 3630+951:
    print('Kerkira: last idx=',idx-1)
  elif w == 3630+952+2034:
    print('Leukada: last idx=', idx-1)
  elif w == 3630+952+2035+167:
    print('North_Zakinthos: last idx=', idx-1)
  elif w == 3630+952+2035+168+417:
    print('Paxoi: last idx=', idx-1)


# Kefalonia: last idx= 2241
# Kerkira: last idx= 2718
# Leukada: last idx= 4083
# North_Zakinthos: last idx= 4146
# Paxoi: last idx= 4315

# %% [markdown]
# # Dataloader

# %%
# !cp -r drive/My\ Drive/joblib/joblib320.tar.gz . 
# !tar -xvzf joblib320.tar.gz 
# !ls
import pickle 
from joblib import dump, load

# X=np.array(load('X_320_80.joblib'),dtype=np.uint8)
# Y=np.array(load('Y_32_8.joblib'),dtype=np.float32)

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets, models
import random
import math
from functools import lru_cache
from lru_cache import lru_cache
from joblib import Memory
location = './cachedir'
memory = Memory(location, verbose=0)

# @lru_cache(maxsize=None)

# GB = 1024**20
# @lru_cache(use_memory_up_to=(1 * GB))

mem={}

def costly_load_cached(idx):  
    if idx not in mem:
      X=np.array(load('drive/My Drive/clc/Xf__'+str(idx)+'.joblib'),dtype=np.uint8)
      Y=np.array(load('drive/My Drive/clc/Yf__'+str(idx)+'.joblib'),dtype=np.float32)
      mem[idx]=(X,Y)
    return mem[idx]


class SimDataset(Dataset):
    def __init__(self, count, first, transform=None, X=None, Y=None):
        #self.input_images, self.target_masks = simulation.generate_random_data(192, 192, count=count)        
        self.input_images=X
        self.target_masks=Y
        self.transform = transform
        self.count=count
        self.first = first
        # self.costly_load_cached = memory.cache(costly_load_cached)
    
    def __len__(self):
        return self.count
    
    def __getitem__(self, idxx): 

        idx=idxx+self.first  

        # X=np.array(load('drive/My Drive/clc/Xf__'+str(idx)+'.joblib'),dtype=np.uint8)
        # Y=np.array(load('drive/My Drive/clc/Yf__'+str(idx)+'.joblib'),dtype=np.float32)
        X,Y = costly_load_cached(idx)


        r=math.floor(random.uniform(0, 4))
        f=random.random()
        # X[i][j][k]
        # Y[k][i][j]
        # image = np.rot90(X, r, (0,1))
        # mask = np.rot90(Y, r,  (1,2))
        if f>0.5:
          X=np.flip(X,1)
          Y=np.flip(Y,2)

        image = np.rot90(X, r, (0,1))
        image = image.copy()
        mask = np.rot90(Y, r,  (1,2))
        mask = mask.copy()
        if self.transform:
            image = self.transform(image)
        
        return [image, mask]

# use same transform for train/val for this example
trans = transforms.Compose([
    transforms.ToTensor(),
])

# train_set = SimDataset(7203-655, 0,  transform = trans)
# val_set = SimDataset(654, 7203-655, transform = trans)


# 4146
# 4315
val_set = SimDataset(2241, 0,  transform = trans)
train_set = SimDataset(4316-2241, 2241, transform = trans)



image_datasets = {
    'train': train_set, 'val': val_set
}

batch_size = 5

dataloaders = {
    'train': DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0),
    'val': DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=0)
}

dataset_sizes = {
    x: len(image_datasets[x]) for x in image_datasets.keys()
}

dataset_sizes
# Out:
# {'train': 2075, 'val': 2241}

# %%
# import torchvision.utils

# def reverse_transform(inp):
#     inp = inp.numpy().transpose((1, 2, 0))
#     inp = np.clip(inp, 0, 1)
#     inp = (inp * 255).astype(np.uint8)
    
#     return inp

# for inputs, masks in dataloaders['val']:
#   plt.figure()
#   plt.imshow(reverse_transform(inputs[3]))

# %%
# cnt=0
# for inputs, masks in dataloaders['train']:
#   plt.figure()
#   plt.imshow(reverse_transform(inputs[0]))
#   cnt+=1
#   if cnt>20:break

# %%
import torchvision.utils

def reverse_transform(inp):
    inp = inp.numpy().transpose((1, 2, 0))
    inp = np.clip(inp, 0, 1)
    inp = (inp * 255).astype(np.uint8)
    
    return inp

# Get a batch of training data
inputs, masks = next(iter(dataloaders['train']))

print(inputs.shape, masks.shape)
for x in [inputs.numpy(), masks.numpy()]:
    print(x.min(), x.max(), x.mean(), x.std())

plt.imshow(reverse_transform(inputs[0]))
# Out:
# torch.Size([5, 4, 320, 320]) torch.Size([5, 29, 32, 32])
# 0.0 1.0 0.219572 0.28928658
# 0.0 1.0 0.03448276 0.18246558

# %%
# n = Conv2D(dim, 3, activation=acti, padding='same')(m)
# n = BatchNormalization()(n) if bn else n
# n = Dropout(do)(n) if do else n
# n = Conv2D(dim, 3, activation=acti, padding='same')(n)
# n = BatchNormalization()(n) if bn else n

import torch
import torch.nn as nn

def double_conv(in_channels, out_channels):
    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, 3, padding=1),
        nn.BatchNorm2d(out_channels),
        nn.ReLU(inplace=True),
        nn.Dropout2d(p=0.4),
        nn.Conv2d(out_channels, out_channels, 3, padding=1),
        nn.BatchNorm2d(out_channels),
        nn.ReLU(inplace=True)
    )   


class UNet(nn.Module):

    def __init__(self, n_class):
        super().__init__()
          
        self.dconv_downA = double_conv(4, 64) #->160,64
        self.dconv_downB = double_conv(64, 256)    #->32,256
        self.dconv_down1 = double_conv(256, 512)    #->16,512
        self.dconv_down2 = double_conv(512, 512)    #->8,512
        self.dconv_down3 = double_conv(512, 512)    #->4,512
        self.dconv_down4 = double_conv(512, 512)    #->2,512       
        self.dconv_down5 = double_conv(512, 512)    #->2,512    
        #512 256 128 64  32  16   8   4   2   1
        #64  128 256 512 512 512 512 512 512 512
        
        #320 160  32  16  8   4   2   1   
        # 4  64  256  512 512 512 512 512  
        self.maxpool = nn.MaxPool2d(2)
        self.upsample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)        
        
        self.maxpool5 = nn.MaxPool2d(5)  
        
        self.dconv_up4 = double_conv(512 + 512, 512)    #->2,512 
        self.dconv_up3 = double_conv(512 + 512, 256)    #->4,512 
        self.dconv_up2 = double_conv(256 + 512, 128)    #->8,512 
        self.dconv_up1 = double_conv(128 + 512, 64)    #->16,512 
        
        self.conv_last = nn.Conv2d(64, n_class, 1)     
        
        
    def forward(self, x):

        convA = self.dconv_downA(x) #320,64
        x = self.maxpool(convA) #160,64

        convB = self.dconv_downB(x) #160,256
        x = self.maxpool5(convB) #32,256

        conv1 = self.dconv_down1(x) #32,512
        x = self.maxpool(conv1) #16,512

        conv2 = self.dconv_down2(x) #16,512
        x = self.maxpool(conv2) #8,512
        
        conv3 = self.dconv_down3(x) #8,512
        x = self.maxpool(conv3) #4,512   
        
        conv4 = self.dconv_down4(x)  #4,512
        x = self.maxpool(conv4)  #2,512

        x = self.dconv_down5(x) #2, 512
        
        x = self.upsample(x)   #4, 512     
        x = torch.cat([x, conv4], dim=1) #4, 512+512
        
        x = self.dconv_up4(x) #4, 512
        x = self.upsample(x)  #8, 512      
        x = torch.cat([x, conv3], dim=1) #8, 512+512

        x = self.dconv_up3(x) #8,256
        x = self.upsample(x)  #16,256      
        x = torch.cat([x, conv2], dim=1) #16, 256+512     

        x = self.dconv_up2(x) #16, 128
        x = self.upsample(x) #32, 128       
        x = torch.cat([x, conv1], dim=1) #32, 128+512  
        
        x = self.dconv_up1(x) #32,64
        
        out = self.conv_last(x) #64, 29
        
        return out

# %%
from torchsummary import summary
import torch
import torch.nn as nn
import pytorch_unet as pytorch_unet

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# model = pytorch_unet.UNet(29)  #29
model = UNet(29)  #29
model = model.to(device)

summary(model, input_size=(4, 320, 320)) #512, 512, 4     3, 224, 224
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 320, 320]           2,368
#        BatchNorm2d-2         [-1, 64, 320, 320]             128
#               ReLU-3         [-1, 64, 320, 320]               0
#          Dropout2d-4         [-1, 64, 320, 320]               0
#             Conv2d-5         [-1, 64, 320, 320]          36,928
#        BatchNorm2d-6         [-1, 64, 320, 320]             128
#               ReLU-7         [-1, 64, 320, 320]               0
#          MaxPool2d-8         [-1, 64, 160, 160]               0
#             Conv2d-9        [-1, 256, 160, 160]         147,712
#       BatchNorm2d-10        [-1, 256, 160, 160]             512
#              ReLU-11        [-1, 256, 160, 160]               0
#         Dropout2d-12        [-1, 256, 160, 160]               0
#            Conv2d-13        [-1, 256, 160, 160]         590,080
# ...

# %%
from collections import defaultdict
import torch.nn.functional as F
from loss import dice_loss

def calc_loss(pred, target, metrics, bce_weight=0.5):
    bce = F.binary_cross_entropy_with_logits(pred, target)
        
    pred = F.sigmoid(pred)
    dice = dice_loss(pred, target)
    
    loss = bce * bce_weight + dice * (1 - bce_weight)
    
    metrics['bce'] += bce.data.cpu().numpy() * target.size(0)
    metrics['dice'] += dice.data.cpu().numpy() * target.size(0)
    metrics['loss'] += loss.data.cpu().numpy() * target.size(0)
    
    return loss

def print_metrics(metrics, epoch_samples, phase):    
    outputs = []
    for k in metrics.keys():
        outputs.append("{}: {:4f}".format(k, metrics[k] / epoch_samples))
        
    print("{}: {}".format(phase, ", ".join(outputs)))    

def train_model(model, optimizer, scheduler, num_epochs=25):
    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 1e10

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
        
        since = time.time()

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                scheduler.step()
                for param_group in optimizer.param_groups:
                    print("LR", param_group['lr'])
                    
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            metrics = defaultdict(float)
            epoch_samples = 0
            pip=0
            for inputs, labels in dataloaders[phase]:
                pip+=1
                # print(pip)
                inputs = inputs.to(device)
                labels = labels.to(device)             

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    
                    #-----------------------------------------
                    
                    # pred = model(inputs)
                    # pred = pred.data.cpu().numpy()
                    # print(pred.shape)

                    # # Change channel-order and make 3 channels for matplot
                    # input_images_rgb = [reverse_transform(inputs.cpu()[0]), reverse_transform(inputs.cpu()[0])]

                    # # Map each channel (i.e. class) to each color
                    # target_masks_rgb = [helper.masks_to_colorimg(labels.cpu().numpy()[0]), helper.masks_to_colorimg(labels.cpu().numpy()[0])]
                    # pred_rgb = [helper.masks_to_colorimg(pred[0]), helper.masks_to_colorimg(pred[0])]

                    # # helper.plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb]) 
                    
                    
                    #-----------------------------------------
                    
                    loss = calc_loss(outputs, labels, metrics)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                epoch_samples += inputs.size(0)

            print_metrics(metrics, epoch_samples, phase)
            epoch_loss = metrics['loss'] / epoch_samples

            # deep copy the model
            if phase == 'val' and epoch_loss < best_loss:
                print("saving best model")
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())
                dump(model, 'drive/My Drive/clc/model_unet320_aug.joblib') 
                dump(model, './model.joblib')
            if phase == 'val':
              dump(model, 'drive/My Drive/clc/model_unet320_aug_last.joblib') 
        time_elapsed = time.time() - since
        print('{:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val loss: {:4f}'.format(best_loss))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
import torch
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import copy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

num_class = 29

model = pytorch_unet.UNet(num_class).to(device)

# Observe that all parameters are being optimized
optimizer_ft = optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-5)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1)

# ---------------------
# X=[]
# XX=[]
# Y=[]
# ---------------------

# model=load('drive/My Drive/clc/model_unet320_aug_last.joblib') 
model = train_model(model, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# cuda:0
# Epoch 0/99
# ----------
# LR 0.0005
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:123: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1569: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# train: bce: 0.129974, dice: 0.213320, loss: 0.171647
# val: bce: 0.134608, dice: 0.192687, loss: 0.163648
# saving best model
# ...

# %% [markdown]
# # testing

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os,sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import helper
import simulation
from joblib import dump, load
X=np.array(load('drive/My Drive/clc/X_320_nooverlap.joblib'),dtype=np.uint8)
Y=np.array(load('drive/My Drive/clc/Y_32_nooverlap.joblib'),dtype=np.float32)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torchvision.utils

def reverse_transform(inp):
    inp = inp.numpy().transpose((1, 2, 0))
    inp = np.clip(inp, 0, 1)
    inp = (inp * 255).astype(np.uint8)
    
    return inp





from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets, models

class SimDataset(Dataset):
    def __init__(self, count=0, transform=None, X=None, Y=None):
        #self.input_images, self.target_masks = simulation.generate_random_data(192, 192, count=count)        
        self.input_images=X
        self.target_masks=Y
        self.transform = transform
    
    def __len__(self):
        return len(self.input_images)
    
    def __getitem__(self, idx):        
        image = self.input_images[idx]
        mask = self.target_masks[idx]
        if self.transform:
            image = self.transform(image)
        
        return [image, mask]

# use same transform for train/val for this example
trans = transforms.Compose([
    transforms.ToTensor(),
])

train_set = SimDataset(100, transform = trans, X=X[:440], Y=Y[:440])
val_set = SimDataset(10, transform = trans, X=X[441:], Y=Y[441:])


image_datasets = {
    'train': train_set, 'val': val_set
}

# %%
model=load('drive/My Drive/clc/model_unet320_aug.joblib')

# %%
batch_size = 2

dataloaders = {
    'train': DataLoader(train_set, batch_size=batch_size, shuffle=False, num_workers=0),
    'val': DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=0)
}

dataset_sizes = {
    x: len(image_datasets[x]) for x in image_datasets.keys()
}

dataset_sizes
# Out:
# {'train': 440, 'val': 44}

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_img_array(img_array, ncol=3):
    nrow = len(img_array) // ncol

    f, plots = plt.subplots(nrow, ncol, sharex='all', sharey='all', figsize=(ncol * 4, nrow * 4))

    for i in range(len(img_array)):
        plots[i // ncol, i % ncol]
        plots[i // ncol, i % ncol].imshow(img_array[i])

from functools import reduce
def plot_side_by_side(img_arrays):
    flatten_list = reduce(lambda x,y: x+y, zip(*img_arrays))

    plot_img_array(np.array(flatten_list), ncol=len(img_arrays))

import itertools
def plot_errors(results_dict, title):
    markers = itertools.cycle(('+', 'x', 'o'))

    plt.title('{}'.format(title))

    for label, result in sorted(results_dict.items()):
        plt.plot(result, marker=next(markers), label=label)
        plt.ylabel('dice_coef')
        plt.xlabel('epoch')
        plt.legend(loc=3, bbox_to_anchor=(1, 0))

    plt.show()

def masks_to_colorimg(masks):

  ids=np.array([1,2,3,5,6,7,10,11,12,15,17,18,20,21,23,24,25,26,28,29,30,31,32,35,37,38,42,43,44])
  ids-=1
  print(ids)
  colors = np.asarray([(230,0,77),(255,0,0),(204,77,242),(204,0,0),(230,204,204),(230,204,230),(166,0,204),(166,77,0),(255,77,255),(255,166,255),(255,230,255),
  (255,255,168),(255,255,0),(230,230,0),(230,128,0),(242,166,77),(230,166,0),(230,230,77),(255,230,166),(255,230,77),(230,204,77),(242,204,166),
  (128,255,0),(0,166,0),(77,255,0),(204,242,77),(166,255,128),(166,230,77),(166,242,0),(230,230,230),(204,204,204),(204,255,204),(0,0,0),(166,230,204),
  (166,166,255),(77,77,255),(204,204,255),(230,230,255),(166,166,230),(0,204,242),(128,242,230),(0,255,166),(166,255,230),(230,242,255),(255,255,255)])
  colors=colors[ids]

   #colors = np.asarray([(201, 58, 64), (242, 207, 1), (0, 152, 75), (101, 172, 228),(56, 34, 132), (160, 194, 56)])

  colorimg = np.ones((masks.shape[1], masks.shape[2], 3), dtype=np.float32) * 255
  channels, height, width = masks.shape

  for y in range(height):
    for x in range(width):
        max_mask = np.argmax(masks[:,y,x])
        colorimg[y,x,:] = colors[max_mask]

  return colorimg.astype(np.uint8)



def masks_to_colorimg_labels(masks):

  ids=np.array([1,2,3,5,6,7,10,11,12,15,17,18,20,21,23,24,25,26,28,29,30,31,32,35,37,38,42,43,44])
  ids-=1
  print(ids)
  colors = np.asarray([(230,0,77),(255,0,0),(204,77,242),(204,0,0),(230,204,204),(230,204,230),(166,0,204),(166,77,0),(255,77,255),(255,166,255),(255,230,255),
  (255,255,168),(255,255,0),(230,230,0),(230,128,0),(242,166,77),(230,166,0),(230,230,77),(255,230,166),(255,230,77),(230,204,77),(242,204,166),
  (128,255,0),(0,166,0),(77,255,0),(204,242,77),(166,255,128),(166,230,77),(166,242,0),(230,230,230),(204,204,204),(204,255,204),(0,0,0),(166,230,204),
  (166,166,255),(77,77,255),(204,204,255),(230,230,255),(166,166,230),(0,204,242),(128,242,230),(0,255,166),(166,255,230),(230,242,255),(255,255,255)])
  colors=colors[ids]

   #colors = np.asarray([(201, 58, 64), (242, 207, 1), (0, 152, 75), (101, 172, 228),(56, 34, 132), (160, 194, 56)])

  colorimg = np.ones((masks.shape[1], masks.shape[2], 3), dtype=np.float32) * 255
  channels, height, width = masks.shape

  for y in range(height):
    for x in range(width):
        selected_colors = colors[masks[:,y,x] > 0]

        if len(selected_colors) > 0:
          colorimg[y,x,:] = np.max(selected_colors, axis=0)

  return colorimg.astype(np.uint8)



def masks_to_id(masks):

  
  colorimg = np.ones((masks.shape[1], masks.shape[2]), dtype=np.int) 
  channels, height, width = masks.shape

  for y in range(height):
    for x in range(width):
        colorimg[y,x] = np.argmax(masks[:,y,x])

  return colorimg.astype(np.uint8)

# %%
import cv2
from torchsummary import summary
import torch
import torch.nn as nn
import pytorch_unet as pytorch_unet

model=load('drive/My Drive/clc/model_unet320_aug.joblib') 


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

i=0
predictions_list=[]
labels_list=[]
for inputs, labels in dataloaders['val']:
    # if i>0: break
    i+=1
    inputs = inputs.to(device)
    labels = labels.to(device)             
    model.eval() 
    # forward
    # track history if only in train
    with torch.set_grad_enabled(False):
        labels=labels.cpu().numpy()
        pred = model(inputs)
        pred = pred.data.cpu().numpy()
       
        target_masks_id= [masks_to_id(x) for x in labels]
        pred_id = [masks_to_id(x) for x in pred]
        
        predictions_list.append(pred_id[0])
        predictions_list.append(pred_id[1])

        labels_list.append(target_masks_id[0])
        labels_list.append(target_masks_id[1])
dump(predictions_list,'drive/My Drive/val_predictions_list_unet320_aug.joblib') 
dump(labels_list,'drive/My Drive/val_labels_list_unet320_aug.joblib') 
print(len(predictions_list))



i=0
predictions_list=[]
labels_list=[]
for inputs, labels in dataloaders['train']:
    # if i>0: break
    i+=1
    inputs = inputs.to(device)
    labels = labels.to(device)             
    model.eval() 
    # forward
    # track history if only in train
    with torch.set_grad_enabled(False):
        labels=labels.cpu().numpy()
        pred = model(inputs)
        pred = pred.data.cpu().numpy()
       
        target_masks_id= [masks_to_id(x) for x in labels]
        pred_id = [masks_to_id(x) for x in pred]
        
        predictions_list.append(pred_id[0])
        predictions_list.append(pred_id[1])

        labels_list.append(target_masks_id[0])
        labels_list.append(target_masks_id[1])
dump(predictions_list,'drive/My Drive/train_predictions_list_unet320_aug.joblib') 
dump(labels_list,'drive/My Drive/train_labels_list_unet320_aug.joblib') 
print(len(predictions_list))
# Out:
# 44
# 440

# %%
import cv2
from torchsummary import summary
import torch
import torch.nn as nn
import pytorch_unet as pytorch_unet

model=load('drive/My Drive/clc/model_unet320_aug_last.joblib') 


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

i=0
predictions_list=[]
labels_list=[]
for inputs, labels in dataloaders['val']:
    # if i>0: break
    i+=1
    inputs = inputs.to(device)
    labels = labels.to(device)             
    model.eval() 
    # forward
    # track history if only in train
    with torch.set_grad_enabled(False):
        labels=labels.cpu().numpy()
        pred = model(inputs)
        pred = pred.data.cpu().numpy()
       
        target_masks_id= [masks_to_id(x) for x in labels]
        pred_id = [masks_to_id(x) for x in pred]
        
        predictions_list.append(pred_id[0])
        predictions_list.append(pred_id[1])

        labels_list.append(target_masks_id[0])
        labels_list.append(target_masks_id[1])
dump(predictions_list,'drive/My Drive/val_predictions_list_unet320_aug_last.joblib') 
dump(labels_list,'drive/My Drive/val_labels_list_unet320_aug_last.joblib') 
print(len(predictions_list))



i=0
predictions_list=[]
labels_list=[]
for inputs, labels in dataloaders['train']:
    # if i>0: break
    i+=1
    inputs = inputs.to(device)
    labels = labels.to(device)             
    model.eval() 
    # forward
    # track history if only in train
    with torch.set_grad_enabled(False):
        labels=labels.cpu().numpy()
        pred = model(inputs)
        pred = pred.data.cpu().numpy()
       
        target_masks_id= [masks_to_id(x) for x in labels]
        pred_id = [masks_to_id(x) for x in pred]
        
        predictions_list.append(pred_id[0])
        predictions_list.append(pred_id[1])

        labels_list.append(target_masks_id[0])
        labels_list.append(target_masks_id[1])
dump(predictions_list,'drive/My Drive/train_predictions_list_unet320_aug_last.joblib') 
dump(labels_list,'drive/My Drive/train_labels_list_unet320_aug_last.joblib') 
print(len(predictions_list))
# Out:
# 44
# 440

# %%
# import cv2
# from torchsummary import summary
# import torch
# import torch.nn as nn
# import pytorch_unet as pytorch_unet

# model=load('drive/My Drive/clc/model_unet320.joblib')


# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# i=0
# predictions_list=[]
# labels_list=[]
# for inputs, labels in dataloaders['val']:
#     # if i>0: break
#     i+=1
#     inputs = inputs.to(device)
#     labels = labels.to(device)             
#     model.eval() 
#     # forward
#     # track history if only in train
#     with torch.set_grad_enabled(False):
#         labels=labels.cpu().numpy()
#         pred = model(inputs)
#         pred = pred.data.cpu().numpy()
       
#         target_masks_id= [masks_to_id(x) for x in labels]
#         pred_id = [masks_to_id(x) for x in pred]
        
#         predictions_list.append(pred_id[0])
#         predictions_list.append(pred_id[1])

#         labels_list.append(target_masks_id[0])
#         labels_list.append(target_masks_id[1])
# dump(predictions_list,'drive/My Drive/val_predictions_list_unet320.joblib') 
# dump(labels_list,'drive/My Drive/val_labels_list_unet320.joblib') 
# print(len(predictions_list))



# i=0
# predictions_list=[]
# labels_list=[]
# for inputs, labels in dataloaders['train']:
#     # if i>0: break
#     i+=1
#     inputs = inputs.to(device)
#     labels = labels.to(device)             
#     model.eval() 
#     # forward
#     # track history if only in train
#     with torch.set_grad_enabled(False):
#         labels=labels.cpu().numpy()
#         pred = model(inputs)
#         pred = pred.data.cpu().numpy()
       
#         target_masks_id= [masks_to_id(x) for x in labels]
#         pred_id = [masks_to_id(x) for x in pred]
        
#         predictions_list.append(pred_id[0])
#         predictions_list.append(pred_id[1])

#         labels_list.append(target_masks_id[0])
#         labels_list.append(target_masks_id[1])
# dump(predictions_list,'drive/My Drive/train_predictions_list_unet320.joblib') 
# dump(labels_list,'drive/My Drive/train_labels_list_unet320.joblib') 
# print(len(predictions_list))

# %%
# import cv2
# from torchsummary import summary
# import torch
# import torch.nn as nn
# import pytorch_unet as pytorch_unet

# model=load('drive/My Drive/clc/model_unet320_last.joblib')


# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# i=0
# predictions_list=[]
# labels_list=[]
# for inputs, labels in dataloaders['val']:
#     # if i>0: break
#     i+=1
#     inputs = inputs.to(device)
#     labels = labels.to(device)             
#     model.eval() 
#     # forward
#     # track history if only in train
#     with torch.set_grad_enabled(False):
#         labels=labels.cpu().numpy()
#         pred = model(inputs)
#         pred = pred.data.cpu().numpy()
       
#         target_masks_id= [masks_to_id(x) for x in labels]
#         pred_id = [masks_to_id(x) for x in pred]
        
#         predictions_list.append(pred_id[0])
#         predictions_list.append(pred_id[1])

#         labels_list.append(target_masks_id[0])
#         labels_list.append(target_masks_id[1])
# dump(predictions_list,'drive/My Drive/val_predictions_list_unet320_last.joblib') 
# dump(labels_list,'drive/My Drive/val_labels_list_unet320_last.joblib') 
# print(len(predictions_list))



# i=0
# predictions_list=[]
# labels_list=[]
# for inputs, labels in dataloaders['train']:
#     # if i>0: break
#     i+=1
#     inputs = inputs.to(device)
#     labels = labels.to(device)             
#     model.eval() 
#     # forward
#     # track history if only in train
#     with torch.set_grad_enabled(False):
#         labels=labels.cpu().numpy()
#         pred = model(inputs)
#         pred = pred.data.cpu().numpy()
       
#         target_masks_id= [masks_to_id(x) for x in labels]
#         pred_id = [masks_to_id(x) for x in pred]
        
#         predictions_list.append(pred_id[0])
#         predictions_list.append(pred_id[1])

#         labels_list.append(target_masks_id[0])
#         labels_list.append(target_masks_id[1])
# dump(predictions_list,'drive/My Drive/train_predictions_list_unet320_last.joblib') 
# dump(labels_list,'drive/My Drive/train_labels_list_unet320_last.joblib') 
# print(len(predictions_list))

# %%
# import cv2
# from torchsummary import summary
# import torch
# import torch.nn as nn
# import pytorch_unet as pytorch_unet

# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# i=0
# predictions_list=[]
# labels_list=[]
# for inputs, labels in dataloaders['val']:
#     # if i>0: break
#     i+=1
#     inputs = inputs.to(device)
#     labels = labels.to(device)             
#     model.eval() 
#     # forward
#     # track history if only in train
#     with torch.set_grad_enabled(False):
#         labels=labels.cpu().numpy()
#         pred = model(inputs)
#         pred = pred.data.cpu().numpy()
#         print(pred.shape)
#         print(labels.shape)
#         # Change channel-order and make 3 channels for matplot

#         pred_=np.zeros((2,29,320,320))
#         for j in range(29):
#           pred_[0][j]=cv2.resize(np.array(pred[0][j]), dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#           pred_[1][j]=cv2.resize(np.array(pred[1][j]), dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#         labels_=np.zeros((2,29,320,320))
#         for j in range(29):
#           labels_[0][j]=cv2.resize(labels[0][j], dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#           labels_[1][j]=cv2.resize(labels[1][j], dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#         labels=labels_
#         pred=pred_

#         input_images_rgb = [reverse_transform(x) for x in inputs.cpu()]
#         input_images_rgb[0]=input_images_rgb[0][:,:,0:3]
#         input_images_rgb[1]=input_images_rgb[1][:,:,0:3]
#         print(input_images_rgb[0].shape)
#         # Map each channel (i.e. class) to each color
#         target_masks_rgb = [masks_to_colorimg_labels(x) for x in labels]
#         pred_rgb = [masks_to_colorimg(x) for x in pred]
        
#         plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb])
#         # plot_side_by_side([target_masks_rgb, target_masks_rgb, pred_rgb])

# %%
# model=load('drive/My Drive/clc/model_unet320_aug_last.joblib')

# i=0
# for inputs, labels in dataloaders['val']:
#     # if i>0: break
#     i+=1
#     inputs = inputs.to(device)
#     labels = labels.to(device)             
#     model.eval() 
#     # forward
#     # track history if only in train
#     with torch.set_grad_enabled(False):
#         labels=labels.cpu().numpy()
#         pred = model(inputs)
#         pred = pred.data.cpu().numpy()
#         print(pred.shape)
#         print(labels.shape)
#         # Change channel-order and make 3 channels for matplot

#         pred_=np.zeros((2,29,320,320))
#         for j in range(29):
#           pred_[0][j]=cv2.resize(np.array(pred[0][j]), dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#           pred_[1][j]=cv2.resize(np.array(pred[1][j]), dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#         labels_=np.zeros((2,29,320,320))
#         for j in range(29):
#           labels_[0][j]=cv2.resize(labels[0][j], dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#           labels_[1][j]=cv2.resize(labels[1][j], dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#         labels=labels_
#         pred=pred_

#         input_images_rgb = [reverse_transform(x) for x in inputs.cpu()]
#         input_images_rgb[0]=input_images_rgb[0][:,:,0:3]
#         input_images_rgb[1]=input_images_rgb[1][:,:,0:3]
#         print(input_images_rgb[0].shape)
#         # Map each channel (i.e. class) to each color
#         target_masks_rgb = [masks_to_colorimg_labels(x) for x in labels]
#         pred_rgb = [masks_to_colorimg(x) for x in pred]
        
#         plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb])
#         # plot_side_by_side([target_masks_rgb, target_masks_rgb, pred_rgb])

# %%
# model=load('drive/My Drive/clc/model_unet320.joblib')

# i=0
# for inputs, labels in dataloaders['val']:
#     # if i>0: break
#     i+=1
#     inputs = inputs.to(device)
#     labels = labels.to(device)             
#     model.eval() 
#     # forward
#     # track history if only in train
#     with torch.set_grad_enabled(False):
#         labels=labels.cpu().numpy()
#         pred = model(inputs)
#         pred = pred.data.cpu().numpy()
#         print(pred.shape)
#         print(labels.shape)
#         # Change channel-order and make 3 channels for matplot

#         pred_=np.zeros((2,29,320,320))
#         for j in range(29):
#           pred_[0][j]=cv2.resize(np.array(pred[0][j]), dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#           pred_[1][j]=cv2.resize(np.array(pred[1][j]), dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#         labels_=np.zeros((2,29,320,320))
#         for j in range(29):
#           labels_[0][j]=cv2.resize(labels[0][j], dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#           labels_[1][j]=cv2.resize(labels[1][j], dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#         labels=labels_
#         pred=pred_

#         input_images_rgb = [reverse_transform(x) for x in inputs.cpu()]
#         input_images_rgb[0]=input_images_rgb[0][:,:,0:3]
#         input_images_rgb[1]=input_images_rgb[1][:,:,0:3]
#         print(input_images_rgb[0].shape)
#         # Map each channel (i.e. class) to each color
#         target_masks_rgb = [masks_to_colorimg_labels(x) for x in labels]
#         pred_rgb = [masks_to_colorimg(x) for x in pred]
        
#         plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb])
#         # plot_side_by_side([target_masks_rgb, target_masks_rgb, pred_rgb])

# %%
# model=load('drive/My Drive/clc/model_unet320_last.joblib')

# i=0
# for inputs, labels in dataloaders['val']:
#     # if i>0: break
#     i+=1
#     inputs = inputs.to(device)
#     labels = labels.to(device)             
#     model.eval() 
#     # forward
#     # track history if only in train
#     with torch.set_grad_enabled(False):
#         labels=labels.cpu().numpy()
#         pred = model(inputs)
#         pred = pred.data.cpu().numpy()
#         print(pred.shape)
#         print(labels.shape)
#         # Change channel-order and make 3 channels for matplot

#         pred_=np.zeros((2,29,320,320))
#         for j in range(29):
#           pred_[0][j]=cv2.resize(np.array(pred[0][j]), dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#           pred_[1][j]=cv2.resize(np.array(pred[1][j]), dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#         labels_=np.zeros((2,29,320,320))
#         for j in range(29):
#           labels_[0][j]=cv2.resize(labels[0][j], dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#           labels_[1][j]=cv2.resize(labels[1][j], dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#         labels=labels_
#         pred=pred_

#         input_images_rgb = [reverse_transform(x) for x in inputs.cpu()]
#         input_images_rgb[0]=input_images_rgb[0][:,:,0:3]
#         input_images_rgb[1]=input_images_rgb[1][:,:,0:3]
#         print(input_images_rgb[0].shape)
#         # Map each channel (i.e. class) to each color
#         target_masks_rgb = [masks_to_colorimg_labels(x) for x in labels]
#         pred_rgb = [masks_to_colorimg(x) for x in pred]
        
#         plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb])
#         # plot_side_by_side([target_masks_rgb, target_masks_rgb, pred_rgb])

# %%
# import cv2
# i=0
# for inputs, labels in dataloaders['train']:
#     # if i>0: break
#     i+=1
#     inputs = inputs.to(device)
#     labels = labels.to(device)             
#     model.eval() 
#     # forward
#     # track history if only in train
#     with torch.set_grad_enabled(False):
#         labels=labels.cpu().numpy()
#         pred = model(inputs)
#         pred = pred.data.cpu().numpy()
#         print(pred.shape)
#         print(labels.shape)
#         # Change channel-order and make 3 channels for matplot

#         pred_=np.zeros((2,29,320,320))
#         for j in range(29):
#           pred_[0][j]=cv2.resize(np.array(pred[0][j]), dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#           pred_[1][j]=cv2.resize(np.array(pred[1][j]), dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#         labels_=np.zeros((2,29,320,320))
#         for j in range(29):
#           labels_[0][j]=cv2.resize(labels[0][j], dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#           labels_[1][j]=cv2.resize(labels[1][j], dsize=(320,320), interpolation=cv2.INTER_NEAREST )
#         labels=labels_
#         pred=pred_

#         input_images_rgb = [reverse_transform(x) for x in inputs.cpu()]
#         input_images_rgb[0]=input_images_rgb[0][:,:,0:3]
#         input_images_rgb[1]=input_images_rgb[1][:,:,0:3]
#         print(input_images_rgb[0].shape)
#         # Map each channel (i.e. class) to each color
#         target_masks_rgb = [masks_to_colorimg_labels(x) for x in labels]
#         pred_rgb = [masks_to_colorimg(x) for x in pred]
        
#         plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb])
#         # plot_side_by_side([target_masks_rgb, target_masks_rgb, pred_rgb])

# %%
# 111a
# 112a
# 121a
# 122
# 123a
# 124a
# 131a
# 132
# 133
# 141a
# 142a
# 211a
# 212
# 213
# 221a
# 222
# 223a
# 231a
# 241
# 242a
# 243a
# 244
# 311a
# 312a
# 313a
# 321a
# 322
# 323a
# 324a
# 331a
# 332a
# 333a
# 334
# 335
# 411a
# 412
# 421a
# 422a
# 423
# 511
# 512
# 521a
# 522a
# 523a
# 999

classes=[111, 112, 121, 123, 124, 131, 141, 142, 211, 221, 223, 231, 242, 243, 311, 312, 313, 321, 323, 324, 331, 332, 333, 411, 421, 422, 521, 522, 523]

ids=np.array([1,2,3,5,6,7,10,11,12,15,17,18,20,21,23,24,25,26,28,29,30,31,32,35,37,38,42,43,44])
ids-=1
# print(ids)
colors = np.asarray([(230,0,77),(255,0,0),(204,77,242),(204,0,0),(230,204,204),(230,204,230),(166,0,204),(166,77,0),(255,77,255),(255,166,255),(255,230,255),
(255,255,168),(255,255,0),(230,230,0),(230,128,0),(242,166,77),(230,166,0),(230,230,77),(255,230,166),(255,230,77),(230,204,77),(242,204,166),
(128,255,0),(0,166,0),(77,255,0),(204,242,77),(166,255,128),(166,230,77),(166,242,0),(230,230,230),(204,204,204),(204,255,204),(0,0,0),(166,230,204),
(166,166,255),(77,77,255),(204,204,255),(230,230,255),(166,166,230),(0,204,242),(128,242,230),(0,255,166),(166,255,230),(230,242,255),(255,255,255)])
data_colors=colors[ids]

# print('len=',(data_colors))





import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
# for c in data_colors:
#   print(c)
#   image = np.ones((4,4,3))
#   for i in range(4):
#     for j in range(4):
#       for k in range(3):
#         image[i][j][k]=int(c[k])
#   # plt.figure
#   plt.imshow(image)
#   plt.show()

a=1
image = np.ones((a*4,a*7,3))
for i in range(4):
  for j in range(7):
      image[a*i:a*(i+1),a*j:a*(j+1),:]=np.array(data_colors[j+7*i,:], int)
      # print(image[a*i:a*(i+1),a*j:a*(j+1),:], "\n\n\n\n")

plt.title("clc class colours found in Ionio")
plt.imshow(np.array(image,int))
plt.show()

# %%
# i=0
# for inputs, labels in dataloaders['train']:
#     # if i>0: break
#     i+=1
#     inputs = inputs.to(device)
#     labels = labels.to(device)             
#     model.eval() 
#     # forward
#     # track history if only in train
#     with torch.set_grad_enabled(False):
#         pred = model(inputs)
#         pred = pred.data.cpu().numpy()
#         print(pred.shape)

#         # Change channel-order and make 3 channels for matplot

#         input_images_rgb = [reverse_transform(x) for x in inputs.cpu()]
#         input_images_rgb[0]=input_images_rgb[0][:,:,0:3]
#         input_images_rgb[1]=input_images_rgb[1][:,:,0:3]
#         print(input_images_rgb[0].shape)
#         # Map each channel (i.e. class) to each color
#         target_masks_rgb = [masks_to_colorimg_labels(x) for x in labels.cpu().numpy()]
#         pred_rgb = [masks_to_colorimg(x) for x in pred]

#         plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb])
#         # plot_side_by_side([target_masks_rgb, target_masks_rgb, pred_rgb])

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_img_array(img_array, ncol=3):
    nrow = len(img_array) // ncol

    f, plots = plt.subplots(nrow, ncol, sharex='all', sharey='all', figsize=(ncol * 4, nrow * 4))

    for i in range(len(img_array)):
        plots[i // ncol, i % ncol]
        plots[i // ncol, i % ncol].imshow(img_array[i])

from functools import reduce
def plot_side_by_side(img_arrays):
    flatten_list = reduce(lambda x,y: x+y, zip(*img_arrays))

    plot_img_array(np.array(flatten_list), ncol=len(img_arrays))

import itertools
def plot_errors(results_dict, title):
    markers = itertools.cycle(('+', 'x', 'o'))

    plt.title('{}'.format(title))

    for label, result in sorted(results_dict.items()):
        plt.plot(result, marker=next(markers), label=label)
        plt.ylabel('dice_coef')
        plt.xlabel('epoch')
        plt.legend(loc=3, bbox_to_anchor=(1, 0))

    plt.show()

def masks_to_colorimg(masks,i):

  ids=np.array([1,2,3,5,6,7,10,11,12,15,17,18,20,21,23,24,25,26,28,29,30,31,32,35,37,38,42,43,44])
  ids-=1
  print(ids)
  colors = np.asarray([(230,0,77),(255,0,0),(204,77,242),(204,0,0),(230,204,204),(230,204,230),(166,0,204),(166,77,0),(255,77,255),(255,166,255),(255,230,255),
  (255,255,168),(255,255,0),(230,230,0),(230,128,0),(242,166,77),(230,166,0),(230,230,77),(255,230,166),(255,230,77),(230,204,77),(242,204,166),
  (128,255,0),(0,166,0),(77,255,0),(204,242,77),(166,255,128),(166,230,77),(166,242,0),(230,230,230),(204,204,204),(204,255,204),(0,0,0),(166,230,204),
  (166,166,255),(77,77,255),(204,204,255),(230,230,255),(166,166,230),(0,204,242),(128,242,230),(0,255,166),(166,255,230),(230,242,255),(255,255,255)])
  colors=colors[ids]

   #colors = np.asarray([(201, 58, 64), (242, 207, 1), (0, 152, 75), (101, 172, 228),(56, 34, 132), (160, 194, 56)])

  colorimg = np.ones((masks.shape[1], masks.shape[2], 3), dtype=np.float32) * 255
  channels, height, width = masks.shape
  for y in range(height):
    for x in range(width):
        idxs=masks[:,y,x] > 0
        # print(idxs)
        for f in range(len(idxs)):
          ff=idxs[f]
          if f<i or f>=i+4:
            idxs[f]=False
        # print(idxs)
        selected_colors = colors[idxs]

        if len(selected_colors) > 0:
          colorimg[y,x,:] = np.max(selected_colors[i:i+4], axis=0)

  return colorimg.astype(np.uint8)



def masks_to_colorimg_labels(masks):

  ids=np.array([1,2,3,5,6,7,10,11,12,15,17,18,20,21,23,24,25,26,28,29,30,31,32,35,37,38,42,43,44])
  ids-=1
  print(ids)
  colors = np.asarray([(230,0,77),(255,0,0),(204,77,242),(204,0,0),(230,204,204),(230,204,230),(166,0,204),(166,77,0),(255,77,255),(255,166,255),(255,230,255),
  (255,255,168),(255,255,0),(230,230,0),(230,128,0),(242,166,77),(230,166,0),(230,230,77),(255,230,166),(255,230,77),(230,204,77),(242,204,166),
  (128,255,0),(0,166,0),(77,255,0),(204,242,77),(166,255,128),(166,230,77),(166,242,0),(230,230,230),(204,204,204),(204,255,204),(0,0,0),(166,230,204),
  (166,166,255),(77,77,255),(204,204,255),(230,230,255),(166,166,230),(0,204,242),(128,242,230),(0,255,166),(166,255,230),(230,242,255),(255,255,255)])
  colors=colors[ids]

   #colors = np.asarray([(201, 58, 64), (242, 207, 1), (0, 152, 75), (101, 172, 228),(56, 34, 132), (160, 194, 56)])

  colorimg = np.ones((masks.shape[1], masks.shape[2], 3), dtype=np.float32) * 255
  channels, height, width = masks.shape

  for y in range(height):
    for x in range(width):
        selected_colors = colors[masks[:,y,x] > 0]

        if len(selected_colors) > 0:
          colorimg[y,x,:] = np.max(selected_colors, axis=0)

  return colorimg.astype(np.uint8)

# %%
# i=0
# for inputs, labels in dataloaders['train']:
#     if i>4: break
   
#     i+=1
#     if i<=4: continue
#     inputs = inputs.to(device)
#     labels = labels.to(device)             
#     model.eval() 
#     # forward
#     # track history if only in train
#     with torch.set_grad_enabled(False):
#         pred = model(inputs)
#         pred = pred.data.cpu().numpy()
#         print(pred.shape)

#         # Change channel-order and make 3 channels for matplot

#         input_images_rgb = [reverse_transform(x) for x in inputs.cpu()]
#         input_images_rgb[0]=input_images_rgb[0][:,:,0:3]
#         input_images_rgb[1]=input_images_rgb[1][:,:,0:3]
#         print(input_images_rgb[0].shape)
#         # Map each channel (i.e. class) to each color
#         for j in range(6):
#           target_masks_rgb = [masks_to_colorimg_labels(x) for x in labels.cpu().numpy()]
#           pred_rgb = [masks_to_colorimg(x,4*j) for x in pred]

#           plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb])
#         # plot_side_by_side([target_masks_rgb, target_masks_rgb, pred_rgb])

# %%
# !pip3 install --user pandas_ml

# %%
import joblib

import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from prettytable import PrettyTable
# from pandas_ml import ConfusionMatrix
from sklearn.metrics import recall_score, precision_score
from sklearn.metrics import f1_score

# %%
def plot_confusion_matrix(df_confusion, title='Confusion matrix', cmap=plt.cm.gray_r):
    plt.matshow(df_confusion, cmap=cmap) # imshow
    #plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(df_confusion.columns))
    plt.xticks(tick_marks, df_confusion.columns, rotation=45)
    plt.yticks(tick_marks, df_confusion.index)
    #plt.tight_layout()
    plt.ylabel(df_confusion.index.name)
    plt.xlabel(df_confusion.columns.name)

def calculate_confusion_matrix(predictions_file_name, targets_file_name):
    prediction_labels = np.array(joblib.load(predictions_file_name))[:238]
    target_labels = np.array(joblib.load(targets_file_name))[:238]
    print(prediction_labels.shape)
    print(target_labels.shape)
    
    n, m, l = prediction_labels.shape
    
    label_set = set()
    for i in range(n):
        for j in range(m):
            for k in range(l):
                label_set.add(prediction_labels[i, j, k])
                label_set.add(target_labels[i, j, k])
    
    label_map = {}
    for label_id in label_set:
        label_map[label_id] = len(label_map)
    
    num_of_labels = len(label_set)
    label_cnts = np.zeros((num_of_labels,), dtype=np.int32)
    
    cf_cv = np.zeros((num_of_labels, num_of_labels), dtype=np.int32)
    hits=0
    misses=0
    preds=[]
    targs=[]
    for i in range(n):
        for j in range(m):
            for k in range(l):
                prediction = label_map[prediction_labels[i, j, k]]
                target = label_map[target_labels[i, j, k]]
                preds.append(prediction)
                targs.append(target)
                if prediction==target:
                  hits+=1
                else:
                  misses+=1
                cf_cv[target][prediction] += 1
                label_cnts[target] += 1

    cm = cf_cv
         
    TP = np.diag(cm)
    FP = np.sum(cm, axis=0) - TP
    FN = np.sum(cm, axis=1) - TP

    num_classes = num_of_labels
    TN = []
    for i in range(num_classes):
        temp = np.delete(cm, i, 0)    # delete ith row
        temp = np.delete(temp, i, 1)  # delete ith column
        TN.append(sum(sum(temp)))

    # for i in range(num_classes):
    #   print(TP[i] + FP[i] + FN[i] + TN[i] == n*m*l)

    print("accuracy = ", hits/(hits+misses))
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    # print("precision = ", precision)
    # print("recall = ", recall)
    # print(cf_cv)
    y_actu = pd.Series(targs, name='Actual')
    y_pred = pd.Series(preds, name='Predicted')
    df_confusion = pd.crosstab(y_actu, y_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
    df_conf_norm = df_confusion / df_confusion.sum(axis=1)

    # plot_confusion_matrix(df_confusion)
    # plot_confusion_matrix(df_conf_norm)
    # print(df_confusion)


    # cm = ConfusionMatrix(y_actu, y_pred)
    # cm.print_stats()

    y_true = y_actu

    
    print("precision score = ", precision_score(y_true, y_pred, average=None, zero_division=1), end="\n\n\n")
    print("recal score = ", recall_score(y_true, y_pred, average=None, zero_division=1), end="\n\n\n")

    print("f1_macro = ", f1_score(y_true, y_pred, zero_division=1, average='macro'), end="\n\n\n")
    print("f1_micro = ", f1_score(y_true, y_pred, zero_division=1, average='micro'), end="\n\n\n")
    print("f1weighted = ", f1_score(y_true, y_pred, zero_division=1, average='weighted'), end="\n\n\n")

# %%
predictions_file_name = 'drive/My Drive/train_predictions_list_unet320_aug_last.joblib'
targets_file_name = 'drive/My Drive/train_labels_list_unet320_aug_last.joblib'

import warnings
warnings.filterwarnings("ignore")

calculate_confusion_matrix(predictions_file_name, targets_file_name)
# Out:
# (238, 32, 32)
# (238, 32, 32)
# accuracy =  0.779473312762605
# precision score =  [1.         0.35737527 1.         1.         1.         1.
#  0.14285714 0.23148456 0.         0.16432992 0.13153042 0.38053245
#  0.32699561 0.         0.41399608 0.49530316 0.43672971 0.49668312
#  0.39534884 0.         1.         0.20116618 1.         0.
#  0.9935192 ]
#
#
# recal score =  [0.         0.37765043 0.         0.         0.         0.
#  0.05392157 0.4459373  0.         0.30844002 0.07692308 0.30323522
#  0.31473661 1.         0.12798221 0.17711276 0.5207333  0.69251545
#  0.02227074 1.         0.         0.34673367 0.         1.
#  0.995493  ]
#
#
# f1_macro =  0.18085199546281414
#
#
# f1_micro =  0.779473312762605
#
#
# f1weighted =  0.7695546717543333

# %%
predictions_file_name = 'drive/My Drive/val_predictions_list_unet320_aug_last.joblib'
targets_file_name = 'drive/My Drive/val_labels_list_unet320_aug_last.joblib'

calculate_confusion_matrix(predictions_file_name, targets_file_name)
# Out:
# (44, 32, 32)
# (44, 32, 32)
# accuracy =  0.9703480113636364
# precision score =  [0.55882353 0.75062344 0.7388535  0.73636364 0.73671613 1.
#  0.61616162 0.71054852 1.         0.99704288]
#
#
# recal score =  [0.76       0.69036697 0.72049689 0.57446809 0.81170886 0.
#  0.7625     0.77176902 0.         0.9952525 ]
#
#
# f1_macro =  0.5928283406726429
#
#
# f1_micro =  0.9703480113636364
#
#
# f1weighted =  0.9693339673367017

# %%
predictions_file_name = 'drive/My Drive/train_predictions_list_unet320_aug.joblib'
targets_file_name = 'drive/My Drive/train_labels_list_unet320_aug.joblib'

calculate_confusion_matrix(predictions_file_name, targets_file_name)
# Out:
# (238, 32, 32)
# (238, 32, 32)
# accuracy =  0.7868057379201681
# precision score =  [1.         0.19791278 1.         1.         0.         1.
#  1.         0.00862069 1.         0.24349158 0.         0.32026287
#  0.34668351 0.32125206 0.72706553 0.43498953 0.47915728 0.
#  0.         1.         0.02586207 1.         0.         0.99190768]
#
#
# recal score =  [0.         0.30429799 0.         0.         0.         0.
#  0.         0.00127959 0.         0.18847795 0.         0.19384779
#  0.40660888 0.43368378 0.19482403 0.6649207  0.70849828 0.
#  1.         0.         0.00251256 0.         1.         0.9969139 ]
#
#
# f1_macro =  0.16013806023901436
#
#
# f1_micro =  0.7868057379201681
#
#
# f1weighted =  0.7704994480797436

# %%
def calculate_radius_error_array(predictions_file_name, targets_file_name):
    prediction_labels = np.array(joblib.load(predictions_file_name))
    target_labels = np.array(joblib.load(targets_file_name))
    print(prediction_labels.shape)
    print(target_labels.shape)
    
    error_cnt_2d = np.sum(prediction_labels != target_labels, axis=0)
    print(error_cnt_2d.shape)
    
    plt.figure()
    plt.imshow(error_cnt_2d, cmap='gray')
    plt.show()
    
    n = error_cnt_2d.shape[0]
    m = error_cnt_2d.shape[1]
    
    radius_error_dict = {}
    radius_cnt_dict = {}
    for i in range(n):
        for j in range(m):
            radius = (i - (n - 1) / 2) ** 2 + (j - (m - 1) / 2) ** 2
            if radius in radius_error_dict:
                radius_error_dict[radius] += error_cnt_2d[i, j]
                radius_cnt_dict[radius] += 1
            else:
                radius_error_dict[radius] = error_cnt_2d[i, j]
                radius_cnt_dict[radius] = 1
                
    print(radius_error_dict)
    
    radius_error_tuples = []
    for radius in radius_error_dict:
        radius_error_tuples.append((radius, radius_error_dict[radius] / radius_cnt_dict[radius]))
    radius_error_tuples.sort()
    
    print(radius_error_tuples)
    
    radius_error_array = []
    for _, radius_error in radius_error_tuples:
        radius_error_array.append(radius_error)
    
    print(radius_error_array)
    
    plt.figure()
    plt.plot(radius_error_array)
    plt.show()

# %%
predictions_file_name = 'drive/My Drive/train_predictions_list_unet320_aug_last.joblib'
targets_file_name = 'drive/My Drive/train_labels_list_unet320_aug_last.joblib'

calculate_radius_error_array(predictions_file_name, targets_file_name)
# Out:
# (440, 32, 32)
# (440, 32, 32)
# (32, 32)
# ...

# %%
predictions_file_name = 'drive/My Drive/val_predictions_list_unet320_aug_last.joblib'
targets_file_name = 'drive/My Drive/val_labels_list_unet320_aug_last.joblib'

calculate_radius_error_array(predictions_file_name, targets_file_name)
# Out:
# (44, 32, 32)
# (44, 32, 32)
# (32, 32)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_img_array(img_array, ncol=3):
    nrow = len(img_array) // ncol

    f, plots = plt.subplots(nrow, ncol, sharex='all', sharey='all', figsize=(ncol * 4, nrow * 4))

    for i in range(len(img_array)):
        plots[i // ncol, i % ncol]
        plots[i // ncol, i % ncol].imshow(img_array[i])

from functools import reduce
def plot_side_by_side(img_arrays):
    flatten_list = reduce(lambda x,y: x+y, zip(*img_arrays))

    plot_img_array(np.array(flatten_list), ncol=len(img_arrays))

def masks_to_colorimg(masks):

  ids=np.array([1,2,3,5,6,7,10,11,12,15,17,18,20,21,23,24,25,26,28,29,30,31,32,35,37,38,42,43,44])
  ids-=1

  colors = np.asarray([(230,0,77),(255,0,0),(204,77,242),(204,0,0),(230,204,204),(230,204,230),(166,0,204),(166,77,0),(255,77,255),(255,166,255),(255,230,255),
  (255,255,168),(255,255,0),(230,230,0),(230,128,0),(242,166,77),(230,166,0),(230,230,77),(255,230,166),(255,230,77),(230,204,77),(242,204,166),
  (128,255,0),(0,166,0),(77,255,0),(204,242,77),(166,255,128),(166,230,77),(166,242,0),(230,230,230),(204,204,204),(204,255,204),(0,0,0),(166,230,204),
  (166,166,255),(77,77,255),(204,204,255),(230,230,255),(166,166,230),(0,204,242),(128,242,230),(0,255,166),(166,255,230),(230,242,255),(255,255,255)])
  colors=colors[ids]

   #colors = np.asarray([(201, 58, 64), (242, 207, 1), (0, 152, 75), (101, 172, 228),(56, 34, 132), (160, 194, 56)])

  colorimg = np.ones((masks.shape[0], masks.shape[1], 3), dtype=np.float32) * 255
  height, width = masks.shape

  for y in range(height):
    for x in range(width):
        colorimg[y,x,:] = colors[masks[y,x]]

  return colorimg.astype(np.uint8)

# %%
def show_map_val(predictions_file_name, targets_file_name):
    prediction_labels = np.array(joblib.load(predictions_file_name))
    target_labels = np.array(joblib.load(targets_file_name))
    paxoi_pred=prediction_labels[[0,3, 4,  10, 11, 12, 15, 21, 22, 23, 27, 28, 29, 35, 36, 37, 42]]
    paxoi_target=target_labels[[0,3, 4,  10, 11, 12, 15, 21, 22, 23, 27, 28, 29, 35, 36, 37, 42]]
    tlist=[]
    plist=[]
    for i in range(len(paxoi_pred)):
        target_mask_rgb = masks_to_colorimg(paxoi_target[i])
        pred_rgb = masks_to_colorimg(paxoi_pred[i])
        tlist.append(target_mask_rgb)
        plist.append(pred_rgb)
#         plt.figure()
#         plt.imshow(target_mask_rgb )
#         plt.title(str(i))
#         plt.show()
    tmp1=np.concatenate((tlist[1],tlist[2],tlist[0]), axis=1)
    tmp2=np.concatenate((tlist[3],tlist[4],tlist[5]), axis=1)
    tmp12=np.concatenate((tmp1,tmp2), axis=0)
    plt.figure()
    plt.imshow(tmp12)
    plt.title('Βόρεια Ζάκυνθος (target)')
    plt.show()
    
    tmp1=np.concatenate((plist[1],plist[2],plist[0]), axis=1)
    tmp2=np.concatenate((plist[3],plist[4],plist[5]), axis=1)
    tmp12=np.concatenate((tmp1,tmp2), axis=0)
    plt.figure()
    plt.imshow(tmp12)
    plt.title('Βόρεια Ζάκυνθος (prediction)')
    plt.show()

    tmp1=np.concatenate((tlist[6],tlist[0],tlist[0]), axis=1)
    tmp2=np.concatenate((tlist[7],tlist[8],tlist[0]), axis=1)
    tmp3=np.concatenate((tlist[0],tlist[11],tlist[12]), axis=1)
    tmp123=np.concatenate((tmp1,tmp2,tmp3), axis=0)
    plt.figure()
    plt.imshow(tmp123)
    plt.title('Παξοί (target)')
    plt.show()

    tmp1=np.concatenate((plist[6],plist[0],plist[0]), axis=1)
    tmp2=np.concatenate((plist[7],plist[8],plist[0]), axis=1)
    tmp3=np.concatenate((plist[0],plist[11],plist[12]), axis=1)
    tmp123=np.concatenate((tmp1,tmp2,tmp3), axis=0)
    plt.figure()
    plt.imshow(tmp123)
    plt.title('Παξοί (prediction)')
    plt.show()
    
    tmp1=np.concatenate((tlist[13],tlist[14],tlist[15]), axis=1)
    tmp2=np.concatenate((tlist[0],tlist[16],tlist[0]), axis=1)
    tmp12=np.concatenate((tmp1,tmp2), axis=0)
    plt.figure()
    plt.imshow(tmp12)
    plt.title('Αντίπαξος (target)')
    plt.show()
    
    
    tmp1=np.concatenate((plist[13],plist[14],plist[15]), axis=1)
    tmp2=np.concatenate((plist[0],plist[16],plist[0]), axis=1)
    tmp12=np.concatenate((tmp1,tmp2), axis=0)
    plt.figure()
    plt.imshow(tmp12)
    plt.title('Αντίπαξος (prediction)')
    plt.show()

# %%
predictions_file_name = 'drive/My Drive/val_predictions_list_unet320_aug_last.joblib'
targets_file_name = 'drive/My Drive/val_labels_list_unet320_aug_last.joblib'

show_map_val(predictions_file_name, targets_file_name)

# %%
predictions_file_name = 'drive/My Drive/val_predictions_list_unet320_aug.joblib'
targets_file_name = 'drive/My Drive/val_labels_list_unet320_aug.joblib'

show_map_val(predictions_file_name, targets_file_name)

# %%
# predictions_file_name = 'drive/My Drive/val_predictions_list_unet320_last.joblib'
# targets_file_name = 'drive/My Drive/val_labels_list_unet320_last.joblib'

# show_map(predictions_file_name, targets_file_name)

# %%
# predictions_file_name = 'drive/My Drive/val_predictions_list_unet320.joblib'
# targets_file_name = 'drive/My Drive/val_labels_list_unet320.joblib'

# show_map(predictions_file_name, targets_file_name)

# %%
def show_map(predictions_file_name, targets_file_name, first, second, name, lim1, lim2):
    prediction_labels = np.array(joblib.load(predictions_file_name))
    target_labels = np.array(joblib.load(targets_file_name))
    
    i = lim1
    res = target_labels[i].copy()
    i+=1
    for j in range(second-1):
      res=np.concatenate((res, target_labels[i]), axis=1)
      i+=1
    while(i<lim2):
      tmp = target_labels[i].copy()
      i+=1
      for j in range(second-1):
        tmp=np.concatenate((tmp, target_labels[i]), axis=1)
        i+=1
      res=np.concatenate((res,tmp), axis=0)
    
    plt.figure()
    plt.imshow(masks_to_colorimg(res))
    plt.title(name+' (target)')
    plt.show()
    
       

    i = lim1
    res = prediction_labels[i].copy()
    i+=1
    for j in range(second-1):
      res=np.concatenate((res, prediction_labels[i]), axis=1)
      i+=1
    while(i<lim2):
      tmp = prediction_labels[i].copy()
      i+=1
      for j in range(second-1):
        tmp=np.concatenate((tmp, prediction_labels[i]), axis=1)
        i+=1
      res=np.concatenate((res,tmp), axis=0)

    plt.figure()
    plt.imshow(masks_to_colorimg(res))
    plt.title(name+' (prediction)')
    plt.show()

# %%
first=2979//320
second=2504//320
predictions_file_name = 'drive/My Drive/train_predictions_list_unet320_aug_last.joblib'
targets_file_name = 'drive/My Drive/train_labels_list_unet320_aug_last.joblib'
name='Κέρκυρα'
lim1=238
lim2=238+63
show_map(predictions_file_name, targets_file_name, first, second, name, lim1, lim2)


# 238

# 63

# 140

# dim= (5559, 4684)

# dim= (2979, 2504)

# dim= (3250, 4678)

# %%
first=2979//320
second=2504//320
predictions_file_name = 'drive/My Drive/train_predictions_list_unet320_aug.joblib'
targets_file_name = 'drive/My Drive/train_labels_list_unet320_aug.joblib'
name='Κέρκυρα'
lim1=238
lim2=238+63
show_map(predictions_file_name, targets_file_name, first, second, name, lim1, lim2)


# 238

# 63

# 140

# dim= (5559, 4684)

# dim= (2979, 2504)

# dim= (3250, 4678)

# %%
first=5559//320
second=4684//320
predictions_file_name = 'drive/My Drive/train_predictions_list_unet320_aug_last.joblib'
targets_file_name = 'drive/My Drive/train_labels_list_unet320_aug_last.joblib'
name='Κεφαλονιά'
lim1=0
lim2=238
show_map(predictions_file_name, targets_file_name, first, second, name, lim1, lim2)


# 238

# 63

# 140

# dim= (5559, 4684)

# dim= (2979, 2504)

# dim= (3250, 4678)

# %%
first=5559//320
second=4684//320
predictions_file_name = 'drive/My Drive/train_predictions_list_unet320_aug.joblib'
targets_file_name = 'drive/My Drive/train_labels_list_unet320_aug.joblib'
name='Κεφαλονιά'
lim1=0
lim2=238
show_map(predictions_file_name, targets_file_name, first, second, name, lim1, lim2)


# 238

# 63

# 140

# dim= (5559, 4684)

# dim= (2979, 2504)

# dim= (3250, 4678)

# %%
first=3250//320-1
second=4678//320
predictions_file_name = 'drive/My Drive/train_predictions_list_unet320_aug_last.joblib'
targets_file_name = 'drive/My Drive/train_labels_list_unet320_aug_last.joblib'
name='Λευκάδα'
lim1=238+63
lim2=238+63+140-15
show_map(predictions_file_name, targets_file_name, first, second, name, lim1, lim2)


# 238

# 63

# 140

# dim= (5559, 4684)

# dim= (2979, 2504)

# dim= (3250, 4678)

# %%
first=3250//320-1
second=4678//320
predictions_file_name = 'drive/My Drive/train_predictions_list_unet320_aug.joblib'
targets_file_name = 'drive/My Drive/train_labels_list_unet320_aug.joblib'
name='Λευκάδα'
lim1=238+63
lim2=238+63+140-15
show_map(predictions_file_name, targets_file_name, first, second, name, lim1, lim2)


# 238

# 63

# 140

# dim= (5559, 4684)

# dim= (2979, 2504)

# dim= (3250, 4678)

# %%
f = open("drive/My Drive/crawl.txt", "r")
val_loss=[]
train_loss=[]
for i in range(43):
    f.readline()
    s=f.readline()
    train_loss.append(float(s[44:-1]))
    s=f.readline()
    val_loss.append(float(s[42:-1]))
    if(f.readline()=='saving best model\n'):
        f.readline()
    f.readline()
    f.readline()
    # print("d",f.readline())

plt.figure
plt.plot(train_loss, label="training loss")
plt.plot(val_loss, label="validation loss")
plt.xlabel('epoch')
plt.ylabel('epoch loss ')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
